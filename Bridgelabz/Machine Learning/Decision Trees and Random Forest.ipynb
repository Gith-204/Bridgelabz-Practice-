# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn import tree
import matplotlib.pyplot as plt

iris = load_iris()
x,y = iris.data, iris.target
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42) 
model = DecisionTreeClassifier(max_depth=4, min_samples_split=3, min_samples_leaf=2)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(f"Accuracy: {model.score(x_test, y_test)}")
print(f"Feature Importances: {model.feature_importances_}")
tree.plot_tree(model, filled=True, feature_names=iris.feature_names)
plt.show()
# Out:
# Accuracy: 1.0
# Feature Importances: [0.01426307 0.         0.56801435 0.41772258]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# Load dataset
iris = load_iris()
X, y = iris.data, iris.target

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create and train model
model = RandomForestClassifier(
    n_estimators=100,      # Number of trees
    max_depth=5,           # Maximum depth of each tree
    min_samples_split=2,
    random_state=42
)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)

# Evaluate
print(f"Accuracy: {model.score(X_test, y_test)}")
print(f"Feature Importances: {model.feature_importances_}")

# Feature importance visualization
for i, importance in enumerate(model.feature_importances_):
    print(f"{iris.feature_names[i]}: {importance:.4f}")
# Out:
# Accuracy: 1.0
# Feature Importances: [0.10461449 0.04148556 0.41732594 0.43657401]
# sepal length (cm): 0.1046
# sepal width (cm): 0.0415
# petal length (cm): 0.4173
# petal width (cm): 0.4366
